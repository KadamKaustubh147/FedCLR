# %% [markdown]
# # Finding insights from amazon dataset

# %% [markdown]
# ### multi-item-intra

# %%
import pandas as pd

cols = ['user_id', 'posi_item']

rest = [f"neg_item{i}" for i in range(1, 1000)]

cols = cols + rest

BASE_m_test = r"C:\Users\kaust\OneDrive\Documents\Honors\datasets\multi-item-intra\dataset"

df_m1_test = pd.read_csv(BASE_m_test + r"\m1\test.txt", sep="\t", header=None, names=cols)
df_m2_test = pd.read_csv(BASE_m_test + r"\m2\test.txt", sep="\t", header=None, names=cols)
df_m3_test = pd.read_csv(BASE_m_test + r"\m3\test.txt", sep="\t", header=None, names=cols)
df_m4_test = pd.read_csv(BASE_m_test + r"\m4\test.txt", sep="\t", header=None, names=cols)
df_m5_test = pd.read_csv(BASE_m_test + r"\m5\test.txt", sep="\t", header=None, names=cols)

# %%
print( "Dataset shapes:" )
# format ml-test - (,)
print( "m1-test:", df_m1_test.shape )
print( "m2-test:", df_m2_test.shape )
print( "m3-test:", df_m3_test.shape )
print( "m4-test:", df_m4_test.shape )
print( "m5-test:", df_m5_test.shape )
# Out:
# Dataset shapes:
# m1-test: (3558, 1001)
# m2-test: (1310, 1001)
# m3-test: (1678, 1001)
# m4-test: (2727, 1001)
# m5-test: (3154, 1001)

# %%
BASE = r"C:\Users\kaust\OneDrive\Documents\Honors\datasets\multi-item-intra\dataset"
